# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
mydata = pd.read_csv('NY property data.csv')

# %%
mydata.head()
# Out:
#    RECORD        BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# 0       1  1000010101  1      1  101      NaN  U S GOVT LAND & BLDGS     P7
# 1       2  1000010201  1      1  201      NaN  U S GOVT LAND & BLDGS     Z9
# 2       3  1000020001  1      2    1      NaN  DEPT OF GENERAL SERVI     Y7
# 3       4  1000020023  1      2   23      NaN  DEPARTMENT OF BUSINES     T2
# 4       5  1000030001  1      3    1      NaN   PARKS AND RECREATION     Q1
#
#   TAXCLASS  LTFRONT  ...  BLDFRONT BLDDEPTH      AVLAND2       AVTOT2  \
# 0        4      500  ...         0        0    3775500.0    8613000.0
# 1        4       27  ...         0        0   11111400.0   80690400.0
# 2        4      709  ...       709      564   32321790.0   40179510.0
# 3        4      793  ...        85      551   13644000.0   15750000.0
# 4        4      323  ...        89       57  106348680.0  107758350.0
#
#        EXLAND2       EXTOT2  EXCD2  PERIOD     YEAR VALTYPE
# ...

# %%
mydata['EASEMENT'].value_counts()
# Out:
# E    4148
# F     296
# G     102
# H      33
# N      19
# I      16
# J       8
# K       5
# L       3
# P       3
# M       2
# U       1
# Name: EASEMENT, dtype: int64

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='EASEMENT', data = mydata, order = mydata['EASEMENT'].value_counts().index)
plot.set_yscale('log')
plt.title('Bar Plot of "EASEMENT" Field')
plt.ylabel('log Scale of Count')
for p in plot.patches:
    height = p.get_height()
    plot.text(p.get_x()+p.get_width()/2., height + 0.1,
        height,ha="center",alpha=0.6,size=16)
plt.savefig('hist.png')

# %%
mydata['OWNER'].value_counts()
# Out:
# PARKCHESTER PRESERVAT    6020
# PARKS AND RECREATION     4255
# DCAS                     2169
# HOUSING PRESERVATION     1904
# CITY OF NEW YORK         1450
#                          ...
# J GRAZI                     1
# SOLER, NULPIANO             1
# IAN K. WENGER               1
# CASSOUTO LYNNE              1
# GARCED, DAVID               1
# Name: OWNER, Length: 863346, dtype: int64

# %%
fig = plt.figure(figsize=(18, 11))
mydata['OWNER'].value_counts().head(20).plot(kind='bar')
plt.title('Bar Plot of Top 20 "OWNER" Field')
plt.savefig('hist1.png',bbox_inches = 'tight')

# %%
mydata['BLDGCL'].value_counts()
# Out:
# R4    139879
# A1    123369
# A5     96984
# B1     84208
# B2     77598
#        ...
# I3         4
# I2         4
# H7         3
# Y5         1
# E6         1
# Name: BLDGCL, Length: 200, dtype: int64

# %%
fig = plt.figure(figsize=(18, 11))
mydata['BLDGCL'].value_counts().head(10).plot(kind='bar')
plt.title('Bar Plot of Top 10 "BLDGCL" Field')
plt.savefig('hist2.png',bbox_inches = 'tight')

# %%
mydata['TAXCLASS'].value_counts()
# Out:
# 1     660721
# 2     188612
# 4     104310
# 2A     40574
# 1B     24738
# 1A     21667
# 2B     13964
# 2C     10795
# 3       4638
# 1C       946
# 1D        29
# Name: TAXCLASS, dtype: int64

# %%
plt.rcParams["figure.figsize"] = [15,8]
plot = sns.countplot(x='TAXCLASS', data = mydata, order = mydata['TAXCLASS'].value_counts().index)
plt.title('Bar Plot of "TAXCLASS" Field')
plt.ylabel('Count')

for p in plot.patches:
    height = p.get_height()
    plot.text(p.get_x()+p.get_width()/2., height + 0.5,
        height,ha="center",alpha=0.6,size=16)
plt.savefig('hist3.png')

# %%
xhigh = 300
plt.xlim(0,xhigh)
temp = mydata[mydata['LTFRONT'] <= xhigh]
sns.distplot(temp['LTFRONT'],bins=100, kde=True)
plt.title('Distribution of "LTFRONT" Field')
plt.savefig('hist4.png')

# %%
xhigh = 300
plt.xlim(0,xhigh)
temp = mydata[mydata['LTDEPTH'] <= xhigh]
sns.distplot(temp['LTDEPTH'],bins=100, kde=True)
plt.title('Distribution of "LTDEPTH" Field')
plt.savefig('hist5.png')

# %%
mydata['EXT'].value_counts()
# Out:
# G     266970
# E      49442
# EG     37893
# Name: EXT, dtype: int64

# %%
plt.rcParams["figure.figsize"] = [10,8]
plot = sns.countplot(x='EXT', data = mydata, order = mydata['EXT'].value_counts().index)
plt.title('Bar Plot of "EXT" Field')
plt.ylabel('Count')

for p in plot.patches:
    height = p.get_height()
    plot.text(p.get_x()+p.get_width()/2., height + 0.5,
        height,ha="center",alpha=0.6,size=16)
plt.savefig('hist6.png')

# %%
xhigh = 50
temp = mydata[mydata['STORIES'] > 0]
temp.count()
plt.xlim(0,xhigh)
temp = temp[temp['STORIES'] <= xhigh]
sns.distplot(temp['STORIES'],bins=51, kde=True)
plt.title('Distribution of "STORIES" Field')
plt.savefig('hist7.png')

# %%
mydata['STADDR'].value_counts()
# Out:
# 501 SURF AVENUE       902
# 330 EAST 38 STREET    817
# 322 WEST 57 STREET    720
# 155 WEST 68 STREET    671
# 20 WEST 64 STREET     657
#                      ...
# 55-11 260 STREET        1
# 43-19 244 STREET        1
# 149-50 121 STREET       1
# 30-19 34 STREET         1
# 138-39 248 STREET       1
# Name: STADDR, Length: 839280, dtype: int64

# %%
fig = plt.figure(figsize=(14, 8))
mydata['STADDR'].value_counts().head(10).plot(kind='bar')
plt.title('Bar Plot of Top 10 "STADDR" Field')
plt.savefig('hist8.png',bbox_inches = 'tight')

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(14, 8))
mydata['ZIP'].value_counts().head(10).plot(kind='bar')
plt.title('Bar Plot of Top 10 "ZIP" Field')
plt.savefig('hist9.png',bbox_inches = 'tight')

# %%
mydata['EXMPTCL'].value_counts()
# Out:
# X1    6912
# X5    5208
# X7     820
# X2     770
# X6     764
# X4     441
# X8     292
# X3     259
# X9     108
# KI       1
# R4       1
# A9       1
# VI       1
# 5        1
# Name: EXMPTCL, dtype: int64

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(14, 8))
mydata['EXMPTCL'].value_counts().head(14).plot(kind='bar')
plt.title('Bar Plot of "EXMPTCL" Field')
# Out:
# Text(0.5, 1.0, 'Bar Plot of "EXMPTCL" Field')

# %%
mydata['PERIOD'].value_counts()
# Out:
# FINAL    1070994
# Name: PERIOD, dtype: int64

# %%
mydata['YEAR'].value_counts()
# Out:
# 2010/11    1070994
# Name: YEAR, dtype: int64

# %%
mydata['VALTYPE'].value_counts()
# Out:
# AC-TR    1070994
# Name: VALTYPE, dtype: int64

# %%
mydata['LTFRONT'].describe()
# Out:
# count    1.070994e+06
# mean     3.663530e+01
# std      7.403284e+01
# min      0.000000e+00
# 25%      1.900000e+01
# 50%      2.500000e+01
# 75%      4.000000e+01
# max      9.999000e+03
# Name: LTFRONT, dtype: float64

# %%
3.663530e+01
# Out:
# 36.6353

# %%
7.403284e+01
# Out:
# 74.03284

# %%
1.900000e+01
# Out:
# 19.0

# %%
2.500000e+01
# Out:
# 25.0

# %%
4.000000e+01
# Out:
# 40.0

# %%
9.999000e+03
# Out:
# 9999.0

# %%
len(mydata['LTFRONT'].unique())
# Out:
# 1297

# %%
mydata['LTDEPTH'].describe()
# Out:
# count    1.070994e+06
# mean     8.886159e+01
# std      7.639628e+01
# min      0.000000e+00
# 25%      8.000000e+01
# 50%      1.000000e+02
# 75%      1.000000e+02
# max      9.999000e+03
# Name: LTDEPTH, dtype: float64

# %%
8.886159e+01
# Out:
# 88.86159

# %%
7.639628e+01
# Out:
# 76.39628

# %%
8.000000e+01
# Out:
# 80.0

# %%
1.000000e+02
# Out:
# 100.0

# %%
1.000000e+02
# Out:
# 100.0

# %%
9.999000e+03
# Out:
# 9999.0

# %%
len(mydata['LTDEPTH'].unique())
# Out:
# 1370

# %%
len(mydata[mydata['LTDEPTH']==0])
# Out:
# 170128

# %%
len(mydata['STORIES'].unique())
# Out:
# 112

# %%
mydata['STORIES'].describe()
# Out:
# count    1.014730e+06
# mean     5.006918e+00
# std      8.365707e+00
# min      1.000000e+00
# 25%      2.000000e+00
# 50%      2.000000e+00
# 75%      3.000000e+00
# max      1.190000e+02
# Name: STORIES, dtype: float64

# %%
5.006918e+00
# Out:
# 5.006918

# %%
8.365707e+00
# Out:
# 8.365707

# %%
1.000000e+00
# Out:
# 1.0

# %%
1.190000e+02
# Out:
# 119.0

# %%
mydata['FULLVAL'].describe()
# Out:
# count    1.070994e+06
# mean     8.742645e+05
# std      1.158243e+07
# min      0.000000e+00
# 25%      3.040000e+05
# 50%      4.470000e+05
# 75%      6.190000e+05
# max      6.150000e+09
# Name: FULLVAL, dtype: float64

# %%
8.742645e+05
# Out:
# 874264.5

# %%
1.158243e+07
# Out:
# 11582430.0

# %%
3.040000e+05
# Out:
# 304000.0

# %%
4.470000e+05
# Out:
# 447000.0

# %%
6.190000e+05
# Out:
# 619000.0

# %%
6.150000e+09
# Out:
# 6150000000.0

# %%
len(mydata['FULLVAL'].unique())
# Out:
# 109324

# %%
len(mydata[mydata['FULLVAL']==0])
# Out:
# 13007

# %%
len(mydata['EXTOT2'].unique())
# Out:
# 48349

# %%
len(mydata[mydata['BLDDEPTH']==0])
# Out:
# 228853

# %%
mydata['AVLAND'].describe()
# Out:
# count    1.070994e+06
# mean     8.506792e+04
# std      4.057260e+06
# min      0.000000e+00
# 25%      9.180000e+03
# 50%      1.367800e+04
# 75%      1.974000e+04
# max      2.668500e+09
# Name: AVLAND, dtype: float64

# %%
8.506792e+04
# Out:
# 85067.92

# %%
4.057260e+06
# Out:
# 4057260.0

# %%
9.180000e+03
# Out:
# 9180.0

# %%
1.367800e+04
# Out:
# 13678.0

# %%
1.974000e+04
# Out:
# 19740.0

# %%
2.668500e+09
# Out:
# 2668500000.0

# %%
mydata['AVTOT'].describe()
# Out:
# count    1.070994e+06
# mean     2.272382e+05
# std      6.877529e+06
# min      0.000000e+00
# 25%      1.837400e+04
# 50%      2.534000e+04
# 75%      4.543800e+04
# max      4.668309e+09
# Name: AVTOT, dtype: float64

# %%
2.272382e+05
# Out:
# 227238.2

# %%
6.877529e+06
# Out:
# 6877529.0

# %%
1.837400e+04
# Out:
# 18374.0

# %%
2.534000e+04
# Out:
# 25340.0

# %%
4.543800e+04
# Out:
# 45438.0

# %%
4.668309e+09
# Out:
# 4668309000.0

# %%
mydata['EXLAND'].describe()
# Out:
# count    1.070994e+06
# mean     3.642389e+04
# std      3.981576e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.620000e+03
# 75%      1.620000e+03
# max      2.668500e+09
# Name: EXLAND, dtype: float64

# %%
3.642389e+04
# Out:
# 36423.89

# %%
3.981576e+06
# Out:
# 3981576.0

# %%
1.620000e+03
# Out:
# 1620.0

# %%
1.620000e+03
# Out:
# 1620.0

# %%
2.668500e+09
# Out:
# 2668500000.0

# %%
mydata['EXTOT'].describe()
# Out:
# count    1.070994e+06
# mean     9.118698e+04
# std      6.508403e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.620000e+03
# 75%      2.090000e+03
# max      4.668309e+09
# Name: EXTOT, dtype: float64

# %%
9.118698e+04
# Out:
# 91186.98

# %%
6.508403e+06
# Out:
# 6508403.0

# %%
1.620000e+03
# Out:
# 1620.0

# %%
2.090000e+03
# Out:
# 2090.0

# %%
4.668309e+09
# Out:
# 4668309000.0

# %%
mydata['BLDFRONT'].describe()
# Out:
# count    1.070994e+06
# mean     2.304277e+01
# std      3.557970e+01
# min      0.000000e+00
# 25%      1.500000e+01
# 50%      2.000000e+01
# 75%      2.400000e+01
# max      7.575000e+03
# Name: BLDFRONT, dtype: float64

# %%
2.304277e+01
# Out:
# 23.04277

# %%
3.557970e+01
# Out:
# 35.5797

# %%
1.500000e+01
# Out:
# 15.0

# %%
2.000000e+01
# Out:
# 20.0

# %%
2.400000e+01
# Out:
# 24.0

# %%
7.575000e+03
# Out:
# 7575.0

# %%
mydata['BLDDEPTH'].describe()
# Out:
# count    1.070994e+06
# mean     3.992284e+01
# std      4.270715e+01
# min      0.000000e+00
# 25%      2.600000e+01
# 50%      3.900000e+01
# 75%      5.000000e+01
# max      9.393000e+03
# Name: BLDDEPTH, dtype: float64

# %%
3.992284e+01
# Out:
# 39.92284

# %%
4.270715e+01
# Out:
# 42.70715

# %%
2.600000e+01
# Out:
# 26.0

# %%
3.900000e+01
# Out:
# 39.0

# %%
5.000000e+01
# Out:
# 50.0

# %%
9.393000e+03
# Out:
# 9393.0

# %%
mydata['AVLAND2'].describe()
# Out:
# count    2.827260e+05
# mean     2.462357e+05
# std      6.178963e+06
# min      3.000000e+00
# 25%      5.705000e+03
# 50%      2.014500e+04
# 75%      6.264000e+04
# max      2.371005e+09
# Name: AVLAND2, dtype: float64

# %%
2.827260e+05
# Out:
# 282726.0

# %%
2.462357e+05
# Out:
# 246235.7

# %%
6.178963e+06
# Out:
# 6178963.0

# %%
3.000000e+00
# Out:
# 3.0

# %%
5.705000e+03
# Out:
# 5705.0

# %%
2.014500e+04
# Out:
# 20145.0

# %%
6.264000e+04
# Out:
# 62640.0

# %%
2.371005e+09
# Out:
# 2371005000.0

# %%
mydata['AVTOT2'].describe()
# Out:
# count    2.827320e+05
# mean     7.139114e+05
# std      1.165253e+07
# min      3.000000e+00
# 25%      3.391200e+04
# 50%      7.996250e+04
# 75%      2.405510e+05
# max      4.501180e+09
# Name: AVTOT2, dtype: float64

# %%
7.139114e+05
# Out:
# 713911.4

# %%
1.165253e+07
# Out:
# 11652530.0

# %%
3.391200e+04
# Out:
# 33912.0

# %%
7.996250e+04
# Out:
# 79962.5

# %%
2.405510e+05
# Out:
# 240551.0

# %%
4.501180e+09
# Out:
# 4501180000.0

# %%
mydata['EXLAND2'].describe()
# Out:
# count    8.744900e+04
# mean     3.512357e+05
# std      1.080221e+07
# min      1.000000e+00
# 25%      2.090000e+03
# 50%      3.048000e+03
# 75%      3.177900e+04
# max      2.371005e+09
# Name: EXLAND2, dtype: float64

# %%
3.512357e+05
# Out:
# 351235.7

# %%
1.080221e+07
# Out:
# 10802210.0

# %%
2.090000e+03
# Out:
# 2090.0

# %%
3.048000e+03
# Out:
# 3048.0

# %%
3.177900e+04
# Out:
# 31779.0

# %%
2.371005e+09
# Out:
# 2371005000.0

# %%
mydata['EXTOT2'].describe()
# Out:
# count    1.308280e+05
# mean     6.567683e+05
# std      1.607251e+07
# min      7.000000e+00
# 25%      2.870000e+03
# 50%      3.706200e+04
# 75%      1.068408e+05
# max      4.501180e+09
# Name: EXTOT2, dtype: float64

# %%
6.567683e+05
# Out:
# 656768.3

# %%
1.607251e+07
# Out:
# 16072510.0

# %%
2.870000e+03
# Out:
# 2870.0

# %%
3.706200e+04
# Out:
# 37062.0

# %%
1.068408e+05
# Out:
# 106840.8

# %%
4.501180e+09
# Out:
# 4501180000.0

# %%
len(mydata['VALTYPE'].unique())
# Out:
# 1

# %%
mydata['B'].value_counts()
# Out:
# 4    358046
# 3    323243
# 1    146220
# 5    136200
# 2    107285
# Name: B, dtype: int64

# %%
mydata['BBLE'].value_counts()
# Out:
# 3071351006    1
# 3072791625    1
# 4060900006    1
# 3073410041    1
# 1006247501    1
#              ..
# 2045350024    1
# 3062190068    1
# 1001421367    1
# 3062540022    1
# 1015621103    1
# Name: BBLE, Length: 1070994, dtype: int64

# %%
plt.rcParams["figure.figsize"] = [10,6]
plot = sns.countplot(x='B', data = mydata, order = mydata['B'].value_counts().index)
plt.title('Bar Plot of "B" Field')
plt.ylabel('Count')

for p in plot.patches:
    height = p.get_height()
    plot.text(p.get_x()+p.get_width()/2., height + 0.5,
        height,ha="center",alpha=0.6,size=16)
plt.savefig('hist11.png')
